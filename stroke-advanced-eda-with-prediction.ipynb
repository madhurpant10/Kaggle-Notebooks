# %% [markdown]
# <a href="https://www.kaggle.com/code/madhurpant/stroke-advanced-eda-with-prediction?scriptVersionId=109844152" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <div style="text-align: center; background-color: #191414;font-size:200%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>Stroke EDA with Prediction</b></div>

# %% [markdown]
# <!-- ### Observations: -->
#
# <h1 style="text-align: left;background-color: #191414; font-size:200%; font-family:Courier New; color: #AFBFFF; padding: 14px; line-height: 1; border-radius:10px"> <b>About Dataset</b></h1>
#
# <blockquote style="margin-right:auto; font-family:Courier New; margin-left:auto; color:white; background-color: #4e2e4e; padding: 1em; margin:24px;">
#
# <ul>
# <li> <font color="white" size=+1.0><b>gender</b></font> :
#     <ul>
#         <li> Male or Female
#     </ul>
# <br>
#
# <li> <font color="white" size=+1.0><b>age:</b></font>
#     <ul>
#     <li> Age of the patient [years]
#     </ul>
# <br>
#
# <li> <font color="white" size=+1.0><b>hypertension</b></font> :
#     <ul>
#         <li> [0: Does not suffer from Hypertension, 1: Suffers from Hypertension]
#     </ul>
#
# <br>
#
# <li> <font color="white" size=+1.0><b>heart_disease</b></font> :
#     <ul>
#         <li> [0: Does not suffer from Heart Disese, 1: Suffers from Heart Disease]
#     </ul>
#
# <br>
#
# <li> <font color="white" size=+1.0><b>ever_married</b></font> :
#     <ul>
#         <li> Yes or No
#     </ul>
#
# <br>
#
# <li> <font color="white" size=+1.0><b>work_type</b></font> :
#     <ul>
#         <li> "Children", "Govt_jov", "Never_worked", "Private" or "Self-employed"
#     </ul>
#
# <br>
#
# <li> <font color="white" size=+1.0><b>Residence_type</b></font> :
#     <ul>
#         <li> Urban or Rural
#     </ul>
#
# <br>
#
# <li> <font color="white" size=+1.0><b>avg_glucose_level</b></font> :
#     <ul>
#         <li> Average Glucose Level in blood
#     </ul>
#
# <br>
#
# <li> <font color="white" size=+1.0><b>bmi</b></font> :
#     <ul>
#         <li> Body Mass Index
#     </ul>
#
# <br>
#
# <li> <font color="white" size=+1.0><b>smoking_status</b></font> :
#     <ul>
#         <li> "formerly smoked", "never smoked", "smokes" or "Unknown"
#     </ul>
#
# <br>
#
# <li> <font color="white" size=+1.0><b>stroke</b></font> :
#     <ul>
#         <li> Output class [1: patient have had a stroke, 0: patient never had a stroke]
#     </ul>
# </blockquote>

# %% [markdown]
# <h1 style="text-align: left;background-color: #191414; font-size:200%; font-family:Courier New; color: #AFBFFF; padding: 14px; line-height: 1; border-radius:10px"> <b>Table of Contents</b></h1>
#
#
# <a id="top"></a>
# <div class="list-group" id="list-tab" role="tablist">
#
#    * [1. Donut Charts](#1)
#    * [2. Histograms](#2)
#    * [3. Box Plots](#3)
#    * [4. Correlation Matrix](#4)
#    * [5. Stroke Sunburst](#5)
#    * [6. 2D Density Contour Plot](#6)
#    * [7. Data Preprocessing](#7)
#    * [8. Machine Learning Models](#8)

# %%
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.figure_factory as ff
import plotly.graph_objects as go
from plotly.subplots import make_subplots

from sklearn.linear_model import LinearRegression

theme_colors = ['#E9EAEC', '#FAD02C', '#90ADC6', '#333652']

font = 'Courier New'
# Out:
# /opt/conda/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %%
df = pd.read_csv('../input/stroke-prediction-dataset/healthcare-dataset-stroke-data.csv')

# %%
df = df.drop(['id'], axis=1)
df['age'] = df['age'].astype('int')

# %%
df
# Out:
#       gender  age  hypertension  heart_disease ever_married      work_type  \
# 0       Male   67             0              1          Yes        Private
# 1     Female   61             0              0          Yes  Self-employed
# 2       Male   80             0              1          Yes        Private
# 3     Female   49             0              0          Yes        Private
# 4     Female   79             1              0          Yes  Self-employed
# ...      ...  ...           ...            ...          ...            ...
# 5105  Female   80             1              0          Yes        Private
# 5106  Female   81             0              0          Yes  Self-employed
# 5107  Female   35             0              0          Yes  Self-employed
# 5108    Male   51             0              0          Yes        Private
# 5109  Female   44             0              0          Yes       Govt_job
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0             Urban             228.69  36.6  formerly smoked       1
# 1             Rural             202.21   NaN     never smoked       1
# 2             Rural             105.92  32.5     never smoked       1
# 3             Urban             171.23  34.4           smokes       1
# 4             Rural             174.12  24.0     never smoked       1
# ...             ...                ...   ...              ...     ...
# 5105          Urban              83.75   NaN     never smoked       0
# 5106          Urban             125.20  40.0     never smoked       0
# 5107          Rural              82.99  30.6     never smoked       0
# 5108          Rural             166.29  25.6  formerly smoked       0
# 5109          Urban              85.28  26.2          Unknown       0
#
# [5110 rows x 11 columns]

# %%
df.describe()
# Out:
#                age  hypertension  heart_disease  avg_glucose_level  \
# count  5110.000000   5110.000000    5110.000000        5110.000000
# mean     43.215264      0.097456       0.054012         106.147677
# std      22.633866      0.296607       0.226063          45.283560
# min       0.000000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.245000
# 50%      45.000000      0.000000       0.000000          91.885000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  4909.000000  5110.000000
# mean     28.893237     0.048728
# std       7.854067     0.215320
# min      10.300000     0.000000
# 25%      23.500000     0.000000
# 50%      28.100000     0.000000
# 75%      33.100000     0.000000
# max      97.600000     1.000000

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
df = df[df['gender'] != 'Other']

# %% [markdown]
# <a id="1"></a>
# # <div style="text-align: center; background-color: #191414;font-size:120%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>1. Donut Charts</b></div>

# %%
gender_count = df.groupby(['gender']).size().reset_index().rename(columns={0: 'count'})
hypertension_count = df.groupby(['hypertension']).size().reset_index().rename(columns={0: 'count'})
heart_disease_count = df.groupby(['heart_disease']).size().reset_index().rename(columns={0: 'count'})
ever_married_count = df.groupby(['ever_married']).size().reset_index().rename(columns={0: 'count'})
work_type_count = df.groupby(['work_type']).size().reset_index().rename(columns={0: 'count'})
residence_type_count = df.groupby(['Residence_type']).size().reset_index().rename(columns={0: 'count'})
smoking_status_count = df.groupby(['smoking_status']).size().reset_index().rename(columns={0: 'count'})
stroke_count = df.groupby(['stroke']).size().reset_index().rename(columns={0: 'count'})

fig = make_subplots(rows=4, cols=2,
                    specs=[[{'type':'domain'}, {'type':'domain'}],
                           [{'type':'domain'}, {'type':'domain'}],
                           [{'type':'domain'}, {'type':'domain'}],
                           [{'type':'domain'}, {'type':'domain'}]
                          ])

## Gender Donut Chart
fig.add_trace(
    go.Pie(
        labels=gender_count['gender'],
        values=gender_count['count'],
        hole=.6,
        title='Gender',
        titlefont={'color':None, 'size': 24},       
        ),
    row=1,col=1
    )

## hypertension Donut Chart
fig.add_trace(
    go.Pie(
        labels=hypertension_count['hypertension'],
        values=hypertension_count['count'],
        hole=.6,
        title='Hypertension',
        titlefont={'color':None, 'size': 24},
        ),
    row=1,col=2
    )

## heart_disease Donut Chart
fig.add_trace(
    go.Pie(
        labels=heart_disease_count['heart_disease'],
        values=heart_disease_count['count'],
        hole=.6,
        title='Heart Disease',
        titlefont={'color':None, 'size': 24},
        ),
    row=2,col=1
    )


## ever_married Donut Chart
fig.add_trace(
    go.Pie(
        labels=ever_married_count['ever_married'],
        values=ever_married_count['count'],
        hole=.6,
        title='Ever Married',
        titlefont={'color':None, 'size': 24},
        ),
    row=2,col=2
    )

## work_type Donut Chart
fig.add_trace(
    go.Pie(
        labels=work_type_count['work_type'],
        values=work_type_count['count'],
        hole=.6,
        title='Work Type',
        titlefont={'color':None, 'size': 24},
        ),
    row=3,col=1
    )

## residence_type Donut Chart
fig.add_trace(
    go.Pie(
        labels=residence_type_count['Residence_type'],
        values=residence_type_count['count'],
        hole=.6,
        title='Residence Type',
        titlefont={'color':None, 'size': 24},
        ),
    row=3,col=2
    )

## smoking_status Donut Chart
fig.add_trace(
    go.Pie(
        labels=smoking_status_count['smoking_status'],
        values=smoking_status_count['count'],
        hole=.6,
        title='Smoking Status',
        titlefont={'color':None, 'size': 24},
        ),
    row=4,col=1
    )

## stroke Donut Chart
fig.add_trace(
    go.Pie(
        labels=stroke_count['stroke'],
        values=stroke_count['count'],
        hole=.6,
        title='Stroke',
        titlefont={'color':None, 'size': 24},
        ),
    row=4,col=2
    )

fig.update_traces(
    hoverinfo='label+value',
    textinfo='label+percent',
    textfont_size=12,
    marker=dict(
#         colors=theme_colors,
        line=dict(color='#EEEEEE',
                  width=2)
        )
    )


fig.layout.update(title="<b> Categorical Features Donut Charts <b>",
                  titlefont={'color':None, 'size': 24, 'family': 'Courier New'},
                  showlegend=False, 
                  height=1200, 
                  width=1000,
                  template='plotly_dark',
                  title_x=0.5
                  )
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a7e0cb66-9215-4525-84dc-1d845d5772e3" class="plotly-graph-div" style="height:1200px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7e0cb66-9215-4525-84dc-1d845d5772e3")) {                    Plotly.newPlot(                        "a7e0cb66-9215-4525-84dc-1d845d5772e3",                        [{"hole":0.6,"labels":["Female","Male"],"title":{"font":{"size":24},"text":"Gender"},"values":[2994,2115],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.80625,1.0]},"textfont":{"size":12},"marker":{"line":{"color":"#EEEEEE","width":2}},"hoverinfo":"label+value","textinfo":"label+percent"},{"hole":0.6,"labels":[0,1],"title":{"font":{"size":24},"text":"Hypertension"},"values":[4611,498],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.80625,1.0]},"textfont":{"size":12},"marker":{"line":{"color":"#EEEEEE","width":2}},"hoverinfo":"label+value","textinfo":"label+percent"},{"hole":0.6,"labels":[0,1],"title":{"font":{"size":24},"text":"Heart Disease"},"values":[4833,276],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.5375,0.73125]},"textfont":{"size":12},"marker":{"line":{"color":"#EEEEEE","width":2}},"hoverinfo":"label+value","textinfo":"label+percent"},{"hole":0.6,"labels":["No","Yes"],"title":{"font":{"size":24},"text":"Ever Married"},"values":[1756,3353],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.5375,0.73125]},"textfont":{"size":12},"marker":{"line":{"color":"#EEEEEE","width":2}},"hoverinfo":"label+value","textinfo":"label+percent"},{"hole":0.6,"labels":["Govt_job","Never_worked","Private","Self-employed","children"],"title":{"font":{"size":24},"text":"Work Type"},"values":[657,22,2924,819,687],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.26875,0.4625]},"textfont":{"size":12},"marker":{"line":{"color":"#EEEEEE","width":2}},"hoverinfo":"label+value","textinfo":"label+percent"},{"hole":0.6,"labels":["Rural","Urban"],"title":{"font":{"size":24},"text":"Residence Type"},"values":[2513,2596],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.26875,0.4625]},"textfont":{"size":12},"marker":{"line":{"color":"#EEEEEE","width":2}},"hoverinfo":"label+value","textinfo":"label+percent"},{"hole":0.6,"labels":["Unknown","formerly smoked","never smoked","smokes"],"title":{"font":{"size":24},"text":"Smoking Status"},"values":[1544,884,1892,789],"type":"pie","domain":{"x":[0.0,0.45],"y":[0.0,0.19375]},"textfont":{"size":12},"marker":{"line":{"color":"#EEEEEE","width":2}},"hoverinfo":"label+value","textinfo":"label+percent"},{"hole":0.6,"labels":[0,1],"title":{"font":{"size":24},"text":"Stroke"},"values":[4860,249],"type":"pie","domain":{"x":[0.55,1.0],"y":[0.0,0.19375]},"textfont":{"size":12},"marker":{"line":{"color":"#EEEEEE","width":2}},"hoverinfo":"label+value","textinfo":"label+percent"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.555555 ...

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align: center; background-color: #191414;font-size:120%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>2. Histograms</b></div>

# %%
fig=make_subplots(rows=2,cols=1,subplot_titles=('<i>Age', '<i>Avg Glucose Level'))
fig.add_trace(go.Histogram(x=df['age'],name='age'),row=1,col=1)
fig.add_trace(go.Histogram(x=df['avg_glucose_level'],name='avg_glucose_level'),row=2,col=1)

fig.update_layout(height=600, width=1000, title_text='<b>Feature Distribution', font_size=20)
fig.update_layout(template='plotly_dark', title_x=0.5, font_family='Courier New')
# Out:
# <div>                            <div id="a2f4f5aa-81bd-45fa-bf69-cdedb25e7382" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2f4f5aa-81bd-45fa-bf69-cdedb25e7382")) {                    Plotly.newPlot(                        "a2f4f5aa-81bd-45fa-bf69-cdedb25e7382",                        [{"name":"age","x":[67,61,80,49,79,81,74,69,59,78,81,61,54,78,79,50,64,75,60,57,71,52,79,82,71,80,65,58,69,59,57,42,82,80,48,82,74,72,58,49,78,54,82,63,60,76,75,58,81,39,76,78,79,77,63,63,82,78,73,54,56,80,67,45,75,78,70,76,59,80,76,67,66,63,52,80,80,79,51,43,59,66,79,68,58,54,61,70,47,74,79,81,57,80,45,78,70,58,57,69,64,77,74,81,57,58,50,54,79,53,79,80,76,45,68,71,61,74,38,77,58,53,80,56,72,72,78,80,82,75,73,78,69,38,68,71,76,76,76,75,82,59,74,69,72,66,65,78,57,70,79,68,80,68,55,77,50,57,71,81,76,71,1,78,70,78,56,79,79,81,64,79,60,80,78,72,80,78,80,81,46,59,32,77,61,63,63,82,82,61,65,51,59,68,72,59,70,69,79,74,74,80,77,78,54,78,81,78,78,63,39,51,63,48,81,79,78,55,76,73,81,79,63,81,49,57,81,74,39,80,81,79,73,77,78,68,57,77,51,60,66,57,68,68,57,14,75,71,78,3,58,8,70,14,47,52,75,32,74,79,79,37,37,40,35,20,42,44,79,65,57,49,71,59,25,67,38,54,70,27,47,58,3,58,14,32,23,55,17,59,13,4,16,67,22,45,66,58,69,58,53,78,44,66,27,43,13,51,30,46,43,79,27,38,78,57,61,37,48,29,22,11,22,53,27,76,57,8,21,18,78,78,33,52,51,11,48,82,54,49,24,37,34,64,66,23,68,55,25,48,79,47,20,60,32,66,43,36,52,29,76,39,76,0,34,72,43,57,44,4,44,18,41,23,53,56,0,25,14,53,4,39,53,5,4,37,70,24,55,70,34,26,39,38,20,17,60,75,31,58,5,13,22,52,61,78,57,21,22,80,7,64,64,38,12,33,3,37,22,24,75,12,63,52,68,5,56,43,40,53,52,31,63,69,64,64,62,2,53,65,22,26,53,20,63,13,21,65,65,42,72,13,29,59,42,13,75,33,43,11,7,16,44,78,25,69,61,43,38,68,26,18,43,43,32,81,25,61,66,54,11,53,78,9,48,31,20,21,42,35,53,60,74,23,55,71,5,14,15,66,56,60,57,29,76,52,42,71,64,39,46,51,31,22,41,28,44,68,49,10,31,67,40,70,38,5,54,30,23,31,72,23,25,51,20,12,57,65,16,43,30,29,54,57,42,18,9,26,40,77,15,76,52,55,5,55,36,46,5,39,12,67,1,72,0,64,27,25,81,32,57,52,54,36,18,45,29,51,23,54,54,18,26,72,5,65,42,47,24,57,51,48,56,30,63,46,53,1,15,59,24,53,39,23,31,5,44,1,40,7,56,42,48,82,52,42,73,55,50,43,33,80,33,74,65,40,52,66,20,51,60,59,58,42,28,57,66,56,48,37,27,15,61,80,43,53,70,58,49,65,54,74,56,79,71,28,9,4,36,78,52,80,28,38,56,75,76,10,48,40,82,61,17,58,12,53,26,48,25,27,31,16,20,2,1,28,32,35,52,55,42,52,18,13,45,29,12,37,30,44,79,38,45,66,19,49,66,47,59,23,79,37,78,70,34,28,29,13,22,56,81,28,9,50,70,30,51,24,17,43,9,50,49,6,30,73,20,42,79,55,27,71,9,23,71,56,31,64,46,55,2,58,78,1,35,64,18,19,47,54,39,37,17,20,31,56,31,82,33,42,20,22,61,31,31,17,30,69,63,19,7,51,38,2,58,69,64,31,59,54,24,19,17,29,42,31,29,23,25,14,66,77,79,52,41,31,39,51,40,48,55,41,39,41,5,38,40,12,20,53,21,70,61,70,38,59,36,31,65,61,2,52,33,5,32,54,51,39,40,19,9,53,23,19,1,48,71,44,53,70,1,49,17,40,46,32,2,40,19,43,46,71,31,41,65,52,20,77,51,37,49,62,17,28,80,45,37,3,26,71,58,59,74,17,62,37,19,59,59,62,80,54,27,4,81,41,27,51,59,51,71,48,49,35,25,31,68,39,32,39,63,69,29,1,58,32,63,57,77,8,21,16,8,71,74,7,19,64,23,75,80,40,24,74,52,54,23,19,23,13,51,60,79,75,69,57,47,33,51,47,15,1,20,6,50,31,15,3,30,17,24,5,33,30,66,40,27,21,55,19,75,71,16,49,10,37,59,7,61,34,9,46,0,50,19,21,2,37,20,50,61,48,82,64,50,1,0,55,29,4,70,35,80,54,39,26,6,41,42,9,55,71,14,77,50,49,51,79,63,66,20,37,22,60,39,53,55,63,57,82,56,41,8,34,75,57,72,21,51,15,24,30,82,62,79,19,45,5,57,31,61,27,61,53,76,57,9,34,51,61,19,50,80,13,55,67,30,67,82,5,81,48,66,38,8,47,27,53,27,36,50,32,58,73,62,50,51,19,30,45,30,28,70,0,23,18,41,52,77,34,67,1,23,59,62,47,71,22,33,27,44,18,47,66,42,13,56,69,65,53,36,69,19,3,15,59,61,28,52,33,80,47,2,48,1,26,62,1,38,28,67,57,40,10,55,7,56,37,69,45,28,52,46,45,21,4,45,71,46,3,79,71,74,52,49,32,62,78,48,18,80,34,40,59,11,35,29, ...

# %% [markdown]
# <a id="3"></a>
# # <div style="text-align: center; background-color: #191414;font-size:120%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>3. Box Plots</b></div>

# %%
stroke_df = df[df['stroke'] == 1]
no_stroke_df = df[df['stroke'] == 0]

fig=make_subplots(rows=2,cols=1,subplot_titles=('<i>Age', '<i>Avg Glucose Level'))

fig.add_trace(go.Box(y=stroke_df['age'], name='stroke'),row=1,col=1)
fig.add_trace(go.Box(y=no_stroke_df['age'], name='no_stroke'),row=1,col=1)

fig.add_trace(go.Box(y=stroke_df['avg_glucose_level'],name='stroke'),row=2,col=1)
fig.add_trace(go.Box(y=no_stroke_df['avg_glucose_level'],name='no_stroke'),row=2,col=1)


fig.update_layout(height=800, width=1000, title_text='<b>Box Plots', font_size=20, showlegend=False)
fig.update_layout(template='plotly_dark', title_x=0.5, font_family='Courier New')
# Out:
# <div>                            <div id="46ce933d-4419-43f2-908d-03b6fb88be1e" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46ce933d-4419-43f2-908d-03b6fb88be1e")) {                    Plotly.newPlot(                        "46ce933d-4419-43f2-908d-03b6fb88be1e",                        [{"name":"stroke","y":[67,61,80,49,79,81,74,69,59,78,81,61,54,78,79,50,64,75,60,57,71,52,79,82,71,80,65,58,69,59,57,42,82,80,48,82,74,72,58,49,78,54,82,63,60,76,75,58,81,39,76,78,79,77,63,63,82,78,73,54,56,80,67,45,75,78,70,76,59,80,76,67,66,63,52,80,80,79,51,43,59,66,79,68,58,54,61,70,47,74,79,81,57,80,45,78,70,58,57,69,64,77,74,81,57,58,50,54,79,53,79,80,76,45,68,71,61,74,38,77,58,53,80,56,72,72,78,80,82,75,73,78,69,38,68,71,76,76,76,75,82,59,74,69,72,66,65,78,57,70,79,68,80,68,55,77,50,57,71,81,76,71,1,78,70,78,56,79,79,81,64,79,60,80,78,72,80,78,80,81,46,59,32,77,61,63,63,82,82,61,65,51,59,68,72,59,70,69,79,74,74,80,77,78,54,78,81,78,78,63,39,51,63,48,81,79,78,55,76,73,81,79,63,81,49,57,81,74,39,80,81,79,73,77,78,68,57,77,51,60,66,57,68,68,57,14,75,71,78],"type":"box","xaxis":"x","yaxis":"y"},{"name":"no_stroke","y":[3,58,8,70,14,47,52,75,32,74,79,79,37,37,40,35,20,42,44,79,65,57,49,71,59,25,67,38,54,70,27,47,58,3,58,14,32,23,55,17,59,13,4,16,67,22,45,66,58,69,58,53,78,44,66,27,43,13,51,30,46,43,79,27,38,78,57,61,37,48,29,22,11,22,53,27,76,57,8,21,18,78,78,33,52,51,11,48,82,54,49,24,37,34,64,66,23,68,55,25,48,79,47,20,60,32,66,43,36,52,29,76,39,76,0,34,72,43,57,44,4,44,18,41,23,53,56,0,25,14,53,4,39,53,5,4,37,70,24,55,70,34,26,39,38,20,17,60,75,31,58,5,13,22,52,61,78,57,21,22,80,7,64,64,38,12,33,3,37,22,24,75,12,63,52,68,5,56,43,40,53,52,31,63,69,64,64,62,2,53,65,22,26,53,20,63,13,21,65,65,42,72,13,29,59,42,13,75,33,43,11,7,16,44,78,25,69,61,43,38,68,26,18,43,43,32,81,25,61,66,54,11,53,78,9,48,31,20,21,42,35,53,60,74,23,55,71,5,14,15,66,56,60,57,29,76,52,42,71,64,39,46,51,31,22,41,28,44,68,49,10,31,67,40,70,38,5,54,30,23,31,72,23,25,51,20,12,57,65,16,43,30,29,54,57,42,18,9,26,40,77,15,76,52,55,5,55,36,46,5,39,12,67,1,72,0,64,27,25,81,32,57,52,54,36,18,45,29,51,23,54,54,18,26,72,5,65,42,47,24,57,51,48,56,30,63,46,53,1,15,59,24,53,39,23,31,5,44,1,40,7,56,42,48,82,52,42,73,55,50,43,33,80,33,74,65,40,52,66,20,51,60,59,58,42,28,57,66,56,48,37,27,15,61,80,43,53,70,58,49,65,54,74,56,79,71,28,9,4,36,78,52,80,28,38,56,75,76,10,48,40,82,61,17,58,12,53,26,48,25,27,31,16,20,2,1,28,32,35,52,55,42,52,18,13,45,29,12,37,30,44,79,38,45,66,19,49,66,47,59,23,79,37,78,70,34,28,29,13,22,56,81,28,9,50,70,30,51,24,17,43,9,50,49,6,30,73,20,42,79,55,27,71,9,23,71,56,31,64,46,55,2,58,78,1,35,64,18,19,47,54,39,37,17,20,31,56,31,82,33,42,20,22,61,31,31,17,30,69,63,19,7,51,38,2,58,69,64,31,59,54,24,19,17,29,42,31,29,23,25,14,66,77,79,52,41,31,39,51,40,48,55,41,39,41,5,38,40,12,20,53,21,70,61,70,38,59,36,31,65,61,2,52,33,5,32,54,51,39,40,19,9,53,23,19,1,48,71,44,53,70,1,49,17,40,46,32,2,40,19,43,46,71,31,41,65,52,20,77,51,37,49,62,17,28,80,45,37,3,26,71,58,59,74,17,62,37,19,59,59,62,80,54,27,4,81,41,27,51,59,51,71,48,49,35,25,31,68,39,32,39,63,69,29,1,58,32,63,57,77,8,21,16,8,71,74,7,19,64,23,75,80,40,24,74,52,54,23,19,23,13,51,60,79,75,69,57,47,33,51,47,15,1,20,6,50,31,15,3,30,17,24,5,33,30,66,40,27,21,55,19,75,71,16,49,10,37,59,7,61,34,9,46,0,50,19,21,2,37,20,50,61,48,82,64,50,1,0,55,29,4,70,35,80,54,39,26,6,41,42,9,55,71,14,77,50,49,51,79,63,66,20,37,22,60,39,53,55,63,57,82,56,41,8,34,75,57,72,21,51,15,24,30,82,62,79,19,45,5,57,31,61,27,61,53,76,57,9,34,51,61,19,50,80,13,55,67,30,67,82,5,81,48,66,38,8,47,27,53,27,36,50,32,58,73,62,50,51,19,30,45,30,28,70,0,23,18,41,52,77,34,67,1,23,59,62,47,71,22,33,27,44,18,47,66,42,13,56,69,65,53,36,69,19,3,15,59,61,28,52,33,80,47,2,48,1,26,62,1,38,28,67,57,40,10,55,7,56,37,69,45,28,52,46,45, ...

# %% [markdown]
# <a id="4"></a>
# # <div style="text-align: center; background-color: #191414;font-size:120%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>4. Correlation Matrix</b></div>

# %%
color_palette = ['#FFFCFE', '#B6E2D3', '#D8F9B1']

corr = df.corr()
fig = go.Figure(data= go.Heatmap(z=corr,
                                 x=corr.index.values,
                                 y=corr.columns.values,
                                 colorscale=color_palette,
                                 text = corr.round(2), texttemplate="%{text}", xgap=3, ygap=3
                                 )
                )

fig.update_layout(title_text='<b>Correlation Matrix<b>',
                  title_x=0.5,
                  titlefont={'size': 24, 'family': 'Courier New'},
                  width=900, height=600,
                  xaxis_showgrid=False,
                  yaxis_showgrid=False,
                  yaxis_autorange='reversed', 
                  paper_bgcolor=None,
                  template='plotly_dark'
                  )

fig.show()
# Out:
# <div>                            <div id="0e843562-3c25-4c6f-b63e-5e8acda4d673" class="plotly-graph-div" style="height:600px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e843562-3c25-4c6f-b63e-5e8acda4d673")) {                    Plotly.newPlot(                        "0e843562-3c25-4c6f-b63e-5e8acda4d673",                        [{"colorscale":[[0.0,"#FFFCFE"],[0.5,"#B6E2D3"],[1.0,"#D8F9B1"]],"text":[[1.0,0.28,0.26,0.24,0.33,0.25],[0.28,1.0,0.11,0.17,0.17,0.13],[0.26,0.11,1.0,0.16,0.04,0.13],[0.24,0.17,0.16,1.0,0.18,0.13],[0.33,0.17,0.04,0.18,1.0,0.04],[0.25,0.13,0.13,0.13,0.04,1.0]],"texttemplate":"%{text}","x":["age","hypertension","heart_disease","avg_glucose_level","bmi","stroke"],"xgap":3,"y":["age","hypertension","heart_disease","avg_glucose_level","bmi","stroke"],"ygap":3,"z":[[1.0,0.27627294837308636,0.2636492737472691,0.23821168620938205,0.33365467880862687,0.2451094876180315],[0.27627294837308636,1.0,0.10829245732188252,0.17453999093649128,0.1677704154218704,0.12789125912919277],[0.2636492737472691,0.10829245732188252,1.0,0.16190732875027894,0.04132209529578959,0.13490484180042844],[0.23821168620938205,0.17453999093649128,0.16190732875027894,1.0,0.17567173570874292,0.13199119156645814],[0.33365467880862687,0.1677704154218704,0.04132209529578959,0.17567173570874292,1.0,0.042341277180277734],[0.2451094876180315,0.12789125912919277,0.13490484180042844,0.13199119156645814,0.042341277180277734,1.0]],"type":"heatmap"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d" ...

# %% [markdown]
# <a id="5"></a>
# # <div style="text-align: center; background-color: #191414;font-size:120%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>5. Stroke Sunburst</b></div>

# %%
## Grouping Datasets
gender_stroke_df = df.groupby(['gender', 'stroke']).size().reset_index().rename(columns={0: 'count'})

hypertension_stroke_df = df.groupby(['hypertension', 'stroke']).size().reset_index().rename(columns={0: 'count'})

married_stroke_df = df.groupby(['ever_married', 'stroke']).size().reset_index().rename(columns={0: 'count'})

work_type_stroke_df = df.groupby(['work_type', 'stroke']).size().reset_index().rename(columns={0: 'count'})

residence_stroke_df = df.groupby(['Residence_type', 'stroke']).size().reset_index().rename(columns={0: 'count'})

smoking_stroke_df = df.groupby(['smoking_status', 'stroke']).size().reset_index().rename(columns={0: 'count'})

## Creating Sunburst Figures
sb1 = px.sunburst(gender_stroke_df, values='count', path=['gender', 'stroke'])
sb2 = px.sunburst(hypertension_stroke_df, values='count', path=['hypertension', 'stroke'])

sb3 = px.sunburst(married_stroke_df, values='count', path=['ever_married', 'stroke'])
sb4 = px.sunburst(work_type_stroke_df, values='count', path=['work_type', 'stroke'])

sb5 = px.sunburst(residence_stroke_df, values='count', path=['Residence_type', 'stroke'])
sb6 = px.sunburst(smoking_stroke_df, values='count', path=['smoking_status', 'stroke'])

## Subplots
fig = make_subplots(rows=3, cols=2, specs=[
    [{"type": "sunburst"}, {"type": "sunburst"}],
    [{"type": "sunburst"}, {"type": "sunburst"}],
    [{"type": "sunburst"}, {"type": "sunburst"}]
], subplot_titles=("Gender and Stroke", "Hypertension and Stroke",
                   "Married and Stroke", "Work Type and Stroke",
                   "Residence and Stroke", "Smoking and Stroke"))

## Plotting Figures
fig.add_trace(sb1.data[0], row=1, col=1)
fig.add_trace(sb2.data[0], row=1, col=2)
fig.add_trace(sb3.data[0], row=2, col=1)
fig.add_trace(sb4.data[0], row=2, col=2)
fig.add_trace(sb5.data[0], row=3, col=1)
fig.add_trace(sb6.data[0], row=3, col=2)

fig.update_traces(textinfo="label+percent parent")

# Update title and height
fig.update_layout(title_text="Stroke Sunbursts", title_x=0.5, height=1300, template='plotly_dark', showlegend=False,
        font=dict(
            family="Rubik",
            size=14)
)

fig.show()
# Out:
# <div>                            <div id="a0a3a672-9c4e-4637-95bc-5f071c47529a" class="plotly-graph-div" style="height:1300px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0a3a672-9c4e-4637-95bc-5f071c47529a")) {                    Plotly.newPlot(                        "a0a3a672-9c4e-4637-95bc-5f071c47529a",                        [{"branchvalues":"total","domain":{"x":[0.0,0.45],"y":[0.7777777777777778,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Female/0","Male/0","Female/1","Male/1","Female","Male"],"labels":["0","0","1","1","Female","Male"],"name":"","parents":["Female","Male","Female","Male","",""],"values":[2853,2007,141,108,2994,2115],"type":"sunburst","textinfo":"label+percent parent"},{"branchvalues":"total","domain":{"x":[0.55,1.0],"y":[0.7777777777777778,1.0]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["0/0","1/0","0/1","1/1","0","1"],"labels":["0","0","1","1","0","1"],"name":"","parents":["0","1","0","1","",""],"values":[4428,432,183,66,4611,498],"type":"sunburst","textinfo":"label+percent parent"},{"branchvalues":"total","domain":{"x":[0.0,0.45],"y":[0.3888888888888889,0.6111111111111112]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["No/0","Yes/0","No/1","Yes/1","No","Yes"],"labels":["0","0","1","1","No","Yes"],"name":"","parents":["No","Yes","No","Yes","",""],"values":[1727,3133,29,220,1756,3353],"type":"sunburst","textinfo":"label+percent parent"},{"branchvalues":"total","domain":{"x":[0.55,1.0],"y":[0.3888888888888889,0.6111111111111112]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Govt_job/0","Never_worked/0","Private/0","Self-employed/0","children/0","Govt_job/1","Private/1","Self-employed/1","children/1","Govt_job","Never_worked","Private","Self-employed","children"],"labels":["0","0","0","0","0","1","1","1","1","Govt_job","Never_worked","Private","Self-employed","children"],"name":"","parents":["Govt_job","Never_worked","Private","Self-employed","children","Govt_job","Private","Self-employed","children","","","","",""],"values":[624,22,2775,754,685,33,149,65,2,657,22,2924,819,687],"type":"sunburst","textinfo":"label+percent parent"},{"branchvalues":"total","domain":{"x":[0.0,0.45],"y":[0.0,0.22222222222222224]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Rural/0","Urban/0","Rural/1","Urban/1","Rural","Urban"],"labels":["0","0","1","1","Rural","Urban"],"name":"","parents":["Rural","Urban","Rural","Urban","",""],"values":[2399,2461,114,135,2513,2596],"type":"sunburst","textinfo":"label+percent parent"},{"branchvalues":"total","domain":{"x":[0.55,1.0],"y":[0.0,0.22222222222222224]},"hovertemplate":"labels=%{label}<br>count=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["Unknown/0","formerly smoked/0","never smoked/0","smokes/0","Unknown/1","formerly smoked/1","never smoked/1","smokes/1","Unknown","formerly smoked","never smoked","smokes"],"labels":["0","0","0","0","1","1","1","1","Unknown","formerly smoked","never smoked","smokes"],"name":"","parents":["Unknown","formerly smoked","never smoked","smokes","Unknown","formerly smoked","never smoked","smokes","","","",""],"values":[1497,814,1802,747,47,70,90,42,1544,884,1892,789],"type":"sunburst","textinfo":"label+percent parent"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5} ...

# %% [markdown]
# ### Observations:
#
# <blockquote style="margin-right:auto; font-family:Courier New; margin-left:auto; color:white; background-color: #4e2e4e; padding: 1em; margin:24px;">
#
# <ul>
# <li> <font color="white" size=+1.0><b>Gender and Stroke</b></font> :
#     <ul>
#         <li> Males: <b>5%</b> had a stroke.
#         <li> Females: <b>5%</b> had a stroke.
# </ul>
#
# <li> <font color="white" size=+1.0><b>Hypertension and Stroke:</b></font>
#     <ul>
#         <li> Hypertension: <b>13%</b> had a stroke.
#         <li> No Hypertension: <b>4%</b> had a stroke.
#     </ul>
# </ul>
#
# <ul>
# <li> <font color="white" size=+1.0><b> Married and Stroke </b></font> :
#     <ul>
#         <li> Married: <b>7%</b> had a stroke.
#         <li> Not Married: <b>2%</b> had a stroke.
#     </ul>
# </ul>
#
# <ul>
# <li> <font color="white" size=+1.0><b> Work Type and Stroke </b></font> :
#     <ul>
#         <li> Private: <b>5%</b> had a stroke.
#         <li> Self Employed: <b>8%</b> had a stroke.
#         <li> Take care of Children: <b>0%</b> had a stroke.
#         <li> Govt. Job: <b>5%</b> had a stroke.
#     </ul>
# </ul>
#
# <ul>
# <li> <font color="white" size=+1.0><b> Residence and Stroke </b></font> :
#     <ul>
#         <li> Urban: <b>5%</b> had a stroke.
#         <li> Rural: <b>5%</b> had a stroke.
#     </ul>
# </ul>
#
# <ul>
# <li> <font color="white" size=+1.0><b> Smoking and Stroke </b></font> :
#     <ul>
#         <li> Never Smoked: <b>5%</b> had a stroke.
#         <li> Unknown: <b>3%</b> had a stroke.
#         <li> Formerly Smoked: <b>8%</b> had a stroke.
#         <li> Smokes: <b>5%</b> had a stroke.
#     </ul>
# </ul>
#
# </blockquote>

# %% [markdown]
# <a id="6"></a>
# # <div style="text-align: center; background-color: #191414;font-size:120%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>6. 2D Density Contour Plot</b></div>

# %%
fig = ff.create_2d_density(
    x=df['age'],
    y=df['avg_glucose_level'],
    title="",
    colorscale=['#7A4579', '#D56073', 'rgb(236,158,105)', (1, 1, 0.2), (0.98,0.98,0.98)],
    hist_color='#B6E2D3'
)

fig.update_layout(
    title="Age vs Average Glucose Level Density Plot",
    xaxis_title="Age",
    yaxis_title="Average Glucose Level",
    title_x=0.5,
    height=600, width=800,
    font=dict(
        family="Rubik",
        size=14
    )
)

fig.show()
# Out:
# <div>                            <div id="2c4c15dc-ea0f-4aad-9f59-5829e414cc01" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2c4c15dc-ea0f-4aad-9f59-5829e414cc01")) {                    Plotly.newPlot(                        "2c4c15dc-ea0f-4aad-9f59-5829e414cc01",                        [{"marker":{"color":"rgb(0, 0, 128)","opacity":0.4,"size":2},"mode":"markers","name":"points","x":[67,61,80,49,79,81,74,69,59,78,81,61,54,78,79,50,64,75,60,57,71,52,79,82,71,80,65,58,69,59,57,42,82,80,48,82,74,72,58,49,78,54,82,63,60,76,75,58,81,39,76,78,79,77,63,63,82,78,73,54,56,80,67,45,75,78,70,76,59,80,76,67,66,63,52,80,80,79,51,43,59,66,79,68,58,54,61,70,47,74,79,81,57,80,45,78,70,58,57,69,64,77,74,81,57,58,50,54,79,53,79,80,76,45,68,71,61,74,38,77,58,53,80,56,72,72,78,80,82,75,73,78,69,38,68,71,76,76,76,75,82,59,74,69,72,66,65,78,57,70,79,68,80,68,55,77,50,57,71,81,76,71,1,78,70,78,56,79,79,81,64,79,60,80,78,72,80,78,80,81,46,59,32,77,61,63,63,82,82,61,65,51,59,68,72,59,70,69,79,74,74,80,77,78,54,78,81,78,78,63,39,51,63,48,81,79,78,55,76,73,81,79,63,81,49,57,81,74,39,80,81,79,73,77,78,68,57,77,51,60,66,57,68,68,57,14,75,71,78,3,58,8,70,14,47,52,75,32,74,79,79,37,37,40,35,20,42,44,79,65,57,49,71,59,25,67,38,54,70,27,47,58,3,58,14,32,23,55,17,59,13,4,16,67,22,45,66,58,69,58,53,78,44,66,27,43,13,51,30,46,43,79,27,38,78,57,61,37,48,29,22,11,22,53,27,76,57,8,21,18,78,78,33,52,51,11,48,82,54,49,24,37,34,64,66,23,68,55,25,48,79,47,20,60,32,66,43,36,52,29,76,39,76,0,34,72,43,57,44,4,44,18,41,23,53,56,0,25,14,53,4,39,53,5,4,37,70,24,55,70,34,26,39,38,20,17,60,75,31,58,5,13,22,52,61,78,57,21,22,80,7,64,64,38,12,33,3,37,22,24,75,12,63,52,68,5,56,43,40,53,52,31,63,69,64,64,62,2,53,65,22,26,53,20,63,13,21,65,65,42,72,13,29,59,42,13,75,33,43,11,7,16,44,78,25,69,61,43,38,68,26,18,43,43,32,81,25,61,66,54,11,53,78,9,48,31,20,21,42,35,53,60,74,23,55,71,5,14,15,66,56,60,57,29,76,52,42,71,64,39,46,51,31,22,41,28,44,68,49,10,31,67,40,70,38,5,54,30,23,31,72,23,25,51,20,12,57,65,16,43,30,29,54,57,42,18,9,26,40,77,15,76,52,55,5,55,36,46,5,39,12,67,1,72,0,64,27,25,81,32,57,52,54,36,18,45,29,51,23,54,54,18,26,72,5,65,42,47,24,57,51,48,56,30,63,46,53,1,15,59,24,53,39,23,31,5,44,1,40,7,56,42,48,82,52,42,73,55,50,43,33,80,33,74,65,40,52,66,20,51,60,59,58,42,28,57,66,56,48,37,27,15,61,80,43,53,70,58,49,65,54,74,56,79,71,28,9,4,36,78,52,80,28,38,56,75,76,10,48,40,82,61,17,58,12,53,26,48,25,27,31,16,20,2,1,28,32,35,52,55,42,52,18,13,45,29,12,37,30,44,79,38,45,66,19,49,66,47,59,23,79,37,78,70,34,28,29,13,22,56,81,28,9,50,70,30,51,24,17,43,9,50,49,6,30,73,20,42,79,55,27,71,9,23,71,56,31,64,46,55,2,58,78,1,35,64,18,19,47,54,39,37,17,20,31,56,31,82,33,42,20,22,61,31,31,17,30,69,63,19,7,51,38,2,58,69,64,31,59,54,24,19,17,29,42,31,29,23,25,14,66,77,79,52,41,31,39,51,40,48,55,41,39,41,5,38,40,12,20,53,21,70,61,70,38,59,36,31,65,61,2,52,33,5,32,54,51,39,40,19,9,53,23,19,1,48,71,44,53,70,1,49,17,40,46,32,2,40,19,43,46,71,31,41,65,52,20,77,51,37,49,62,17,28,80,45,37,3,26,71,58,59,74,17,62,37,19,59,59,62,80,54,27,4,81,41,27,51,59,51,71,48,49,35,25,31,68,39,32,39,63,69,29,1,58,32,63,57,77,8,21,16,8,71,74,7,19,64,23,75,80,40,24,74,52,54,23,19,23,13,51,60,79,75,69,57,47,33,51,47,15,1,20,6,50,31,15,3,30,17,24,5,33,30,66,40,27,21,55,19,75,71,16,49,10,37,59,7,61,34,9,46,0,50,19,21,2,37,20,50,61,48,82,64,50,1,0,55,29,4,70,35,80,54,39,26,6,41,42,9,55,71,14,77,50,49,51,79,63,66,20,37,22,60,39,53,55,63,57,82,56,41,8,34,75,57,72,21,51,15,24,30,82,62,79,19,45,5,57,31,61,27,61,53,76,57,9,34,51,61,19,50,80,13,55,67,30,67,82,5,81,48,66,38,8,47,27,53,27,36,50,32,58,73,62,50,51,19,30,45,30,28,70,0,23,18,41,52,77,34,67,1,23,59,62,47,71,22,33,27,44,18,47,66,42,13,56,69,65,53,36,69,19,3,15,59,61,28,52,33,80,47,2,48,1,26,62,1,38,28,67,57,40,10,55,7,56,37,69,45,2 ...

# %% [markdown]
# <a id="7"></a>
# # <div style="text-align: center; background-color: #191414;font-size:120%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>7. Data Preprocessing</b></div>

# %%
# Converting gender, ever_married and Residence_type into 0's and 1's
df['gender']=df['gender'].apply(lambda x : 1 if x=='Male' else 0) 
df["ever_married"] = df["ever_married"].apply(lambda x: 1 if x=="Yes" else 0)
df["Residence_type"] = df["Residence_type"].apply(lambda x: 1 if x=="Urban" else 0)

# %%
df = pd.get_dummies(data=df, columns=['smoking_status'])
df = pd.get_dummies(data=df, columns=['work_type'])

# %%
df = df.dropna()

# %%
X = df.drop(['stroke'], axis=1).values 
y = df['stroke'].values

# %% [markdown]
# <a id="8"></a>
# # <div style="text-align: center; background-color: #191414;font-size:120%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>8. Machine Learning Models</b></div>

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
rfc = RandomForestClassifier(n_estimators = 100)
rfc.fit(X_train, y_train)

#Score 
rfc_score = rfc.score(X_train, y_train)
rfc_test = rfc.score(X_test, y_test)

# Model Testing
y_pred = rfc.predict(X_test)

# Evaluation
rfc_cm = confusion_matrix(y_test,y_pred)
print(f'Training Score: {rfc_score.round(3)}')
print(f'Testing Score: {rfc_test.round(3)}')

conf_matrix = pd.DataFrame(data=rfc_cm,columns=['Predicted:0','Predicted:1'],index=['Actual:0','Actual:1'])
print(f'Accuracy Score: {accuracy_score(y_test,y_pred).round(3)}')
# Out:
# Training Score: 1.0
# Testing Score: 0.952
# Accuracy Score: 0.952

# %%
z=rfc_cm
fig = ff.create_annotated_heatmap(z, x=['Not Stroke','Stroke'], y=['Predicted Not Stroke','Predicted Stroke'], colorscale='Fall',xgap=3,ygap=3)
fig['data'][0]['showscale'] = True

fig.update_layout(title_text='<b>Confusion Matrix for Random Forest Classifier<b>',
                  title_x=0.5,
                  titlefont={'size': 24, 'family': 'Courier New'},
                  width=900, height=400,
                  xaxis_showgrid=False,
                  yaxis_showgrid=False,
                  yaxis_autorange='reversed', 
                  paper_bgcolor=None,
                  template='plotly_dark'
                  )

fig.show()
# Out:
# <div>                            <div id="d9b28f3f-2e4e-4b60-9e98-bfa987842d97" class="plotly-graph-div" style="height:400px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9b28f3f-2e4e-4b60-9e98-bfa987842d97")) {                    Plotly.newPlot(                        "d9b28f3f-2e4e-4b60-9e98-bfa987842d97",                        [{"colorscale":[[0.0,"rgb(61, 89, 65)"],[0.16666666666666666,"rgb(119, 136, 104)"],[0.3333333333333333,"rgb(181, 185, 145)"],[0.5,"rgb(246, 237, 189)"],[0.6666666666666666,"rgb(237, 187, 138)"],[0.8333333333333334,"rgb(222, 138, 90)"],[1.0,"rgb(202, 86, 44)"]],"reversescale":false,"showscale":true,"x":["Not Stroke","Stroke"],"xgap":3,"y":["Predicted Not Stroke","Predicted Stroke"],"ygap":3,"z":[[935,0],[47,0]],"type":"heatmap"}],                        {"annotations":[{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"935","x":"Not Stroke","xref":"x","y":"Predicted Not Stroke","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"Stroke","xref":"x","y":"Predicted Not Stroke","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"47","x":"Not Stroke","xref":"x","y":"Predicted Stroke","yref":"y"},{"font":{"color":"#FFFFFF"},"showarrow":false,"text":"0","x":"Stroke","xref":"x","y":"Predicted Stroke","yref":"y"}],"xaxis":{"dtick":1,"gridcolor":"rgb(0, 0, 0)","side":"top","ticks":"","showgrid":false},"yaxis":{"dtick":1,"ticks":"","ticksuffix":"  ","showgrid":false,"autorange":"reversed"},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"col ...

# %% [markdown]
# <a id=""></a>
# # <div style="text-align: center; background-color: #191414;font-size:120%; font-family:Courier New; color: #AFBFFF; padding: 20px; line-height: 1;border-radius:10px"><b>The End</b></div>
#
# <a href="#top">Back to top</a>
